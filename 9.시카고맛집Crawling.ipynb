# %%
# f12

# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup

# %%
header = {'User-Agent': 'Mozilla/5.0'}
url = "https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago/"
req = Request(url, headers = header)
html =urlopen(req)

# %%
soup = BeautifulSoup(html, 'html.parser')   #html.parser이용 soup 에 넣겠다

# %%
#soup

# %%
#print(soup.find_all('div', 'sammy'))

# %%
len(soup.find_all('div', 'sammy'))
# Out:
# 50

# %%
print(soup.find_all('div', 'sammy')[0])
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>

# %%
tmp = soup.find_all('div', 'sammy')[0]
tmp.find(class_='sammyRank')
# Out:
# <div class="sammyRank">1</div>

# %%
tmp.find(class_='sammyRank').get_text()
# Out:
# '1'

# %%
tmp.find(class_='sammyListing').get_text()
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
# 앵커 태그 열기 a href 
tmp.find('a')
# Out:
# <a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a>

# %%
tmp.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
# BLT 와 Old Oak Tap 분리 ==> Regular Expression 
tmp.find(class_='sammyListing').get_text()
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
import re 
#reg expression

# %%
tmp_string = tmp.find(class_='sammyListing').get_text()

# %%
tmp_string
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
re.split(('\n|\r\n'), tmp_string)
# \r = Carriage return  ===> Linux 와 Windows 모두 호환되게 
# \n : Linux  ==> (자동으로) \r\n : Windows
# Out:
# ['BLT', 'Old Oak Tap', 'Read more ']

# %%
# 마지막 빼기 = [0], [1]만 
print(re.split(('\n|\r\n'), tmp_string)[0])
print(re.split(('\n|\r\n'), tmp_string)[1])
# Out:
# BLT
# Old Oak Tap

# %%
from urllib.parse import urljoin

rank = []
main_menu = []
cafe_name = []
url_ad = []

url_base='https://www.chicagomag.com'

list_soup = soup.find_all('div', 'sammy')

for item in list_soup: 
    rank.append(item.find(class_='sammyRank').get_text()) 
    tmp_string = item.find(class_='sammyListing').get_text()
    
    main_menu.append(re.split(('\n|\r\n'), tmp_string)[0])
    cafe_name.append(re.split(('\n|\r\n'), tmp_string)[1])
    
    url_ad.append(urljoin(url_base, item.find('a')['href']))

# %%
#main_menu

# %%
#rank

# %%
#cafe_name

# %%
#url_ad

# %%
# 개수가 50개 가 다 맞는지 - 확인 해주기 

len(rank), len(main_menu), len(cafe_name), len(url_ad)
# Out:
# (50, 50, 50, 50)

# %%
import pandas as pd

# 가지고온 data -> padnas dataframe 으로 만들기 - dict 이용 
# column 명 : rank, main, cafe, url

# %%
df = {'Rank':rank, 'Cafe':cafe_name, 'Menu':main_menu,  'URL':url_ad}

df = pd.DataFrame(df)

df.head()
# Out:
#   Rank                    Cafe               Menu  \
# 0    1             Old Oak Tap                BLT
# 1    2               Au Cheval      Fried Bologna
# 2    3                    Xoco  Woodland Mushroom
# 3    4               Al’s Deli         Roast Beef
# 4    5  Publican Quality Meats               PB&L
#
#                                                  URL
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
# 꼭 확인 해보기

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    50 non-null     object
#  1   Cafe    50 non-null     object
#  2   Menu    50 non-null     object
#  3   URL     50 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
# 저장하기 

df.to_csv('data/chicago_rank.csv', sep=',')

# %%
# 주소 

header = {'User-Agent': 'Mozilla/5.0'}
url = df['URL'][0]
req = Request(url, headers = header)
html = urlopen(req)

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# [<meta charset="utf-8"/>,
#  <meta content="IE=edge" http-equiv="X-UA-Compatible">
#  <link href="https://gmpg.org/xfn/11" rel="profile"/>
#  <title>1. Old Oak Tap BLT – Chicago Magazine</title>
#  <style type="text/css">			.heateorSssInstagramBackground{background:radial-gradient(circle at 30% 107%,#fdf497 0,#fdf497 5%,#fd5949 45%,#d6249f 60%,#285aeb 90%)}
#  						div.heateor_sss_horizontal_sharing i.heateorSssInstagramBackground{background:#000!important;}div.heateor_sss_standard_follow_icons_container i.heateorSssInstagramBackground{background:#000;}
#  										.heateor_sss_horizontal_sharing .heateorSssSharing,.heateor_sss_standard_follow_icons_container .heateorSssSharing{
#  							background-color: #000;
#  							color: #fff;
#  						border-width: 0px;
#  			border-style: solid;
#  			border-color: transparent;
#  		}
#  				.heateor_sss_horizontal_sharing .heateorSssTCBackground{
#  			color:#666;
#  		}
# ...

# %%
print(soup.find('p', 'addy').get_text())

#div-p-class=addy-em
# Out:
# $10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com

# %%
tmp_str = soup.find('p', 'addy').get_text()
tmp_str.split()
# Out:
# ['$10.', '2109', 'W.', 'Chicago', 'Ave.,', '773-772-0406,', 'theoldoaktap.com']

# %%
# 가격 꺼내기
tmp_str.split()[0]
# Out:
# '$10.'

# %%
# . 없애기 (문자열 바꾸기)
# tmp_str.split()[0].replace('.','')
tmp_str.split()[0][:-1]
# Out:
# '$10'

# %%
# 주소 가져오기 (붙이기)

# -2 대신 5쓰면 안됨 -> 주소가 얼마나 긴지 모르니까 
tmp_str.split()[1:-2]
# Out:
# ['2109', 'W.', 'Chicago', 'Ave.,']

# %%
# 문자열 JOIN
' '.join(tmp_str.split()[1:-2])
# Out:
# '2109 W. Chicago Ave.,'

# %%
price = []
ad = []

for n in df.index[:3]: 
    url = df['URL'][n]
    req = Request(url, headers = header)
    html = urlopen(req)
    soup = BeautifulSoup(html, 'html.parser')
    
    line_data = soup.find('p', 'addy').get_text()

    price.append(line_data.split()[0][:-1]) 
    ad.append(' '.join(tmp_str.split()[1:-2]))

# %%
price
# Out:
# ['$10', '$9', '$9.50']

# %%
ad
# Out:
# ['2109 W. Chicago Ave.,', '2109 W. Chicago Ave.,', '2109 W. Chicago Ave.,']

# %%
# 진행 프로세스 바 

from tqdm.notebook import tqdm

# %%
import time

item_total = tqdm(df.index)
price = []
ad = []

for n in item_total: 
    url = df['URL'][n]
    req = Request(url, headers = header)
    html = urlopen(req)
    soup = BeautifulSoup(html, 'html.parser')
    
    line_data = soup.find('p', 'addy').get_text()
    price.append(line_data.split()[0][:-1]) 
    ad.append(' '.join(line_data.split()[1:-2]))
    
    # dealy 주기 (50번 돌아야하니)
    time.sleep(0.05)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# 확인
len(price), len(ad)
# Out:
# (50, 50)

# %%
price 
# data 하나하나 꼭 확인하기 -----------------제발---------------------
# Out:
# ['$10',
#  '$9',
#  '$9.50',
#  '$9.40',
#  '$10',
#  '$7.25',
#  '$16',
#  '$10',
#  '$9',
#  '$17',
#  '$11',
#  '$5.49',
#  '$14',
#  '$10',
#  '$13',
#  '$4.50',
#  '$11.95',
#  '$11.50',
#  '$6.25',
#  '$15',
#  '$5',
#  '$6',
#  '$8',
#  '$5.99',
#  '$7.52',
#  '$11.95',
#  '$7.50',
#  '$12.95',
#  '$7',
#  '$21',
#  '$9.79',
#  '$9.75',
#  '$13',
#  '$7.95',
#  '$9',
#  '$9',
#  '$8',
#  '$8',
#  '$7',
#  '$6',
#  '$7.25',
#  '$11',
#  '$6',
#  '$9',
#  '$5.49',
#  '$8',
#  '$6.50',
#  '$7.50',
#  '$8.75',
#  '$6.85']

# %%
ad
# data 하나하나 꼭 확인하기 -----------------제발---------------------
# Out:
# ['2109 W. Chicago Ave.,',
#  '800 W. Randolph St.,',
#  '445 N. Clark St.,',
#  '914 Noyes St., Evanston,',
#  '825 W. Fulton Mkt.,',
#  '100 E. Walton',
#  '1639 S. Wabash Ave.,',
#  '2211 W. North Ave.,',
#  '3619 W. North Ave.,',
#  '3267 S. Halsted St.,',
#  '2537 N. Kedzie Blvd.,',
#  'Multiple',
#  '3124 N. Broadway,',
#  '3455 N. Southport Ave.,',
#  '2657 N. Kedzie Ave.,',
#  '1120 W. Grand Ave.,',
#  '1141 S. Jefferson St.,',
#  '333 E. Benton Pl.,',
#  '1411 N. Wells St.,',
#  '1747 N. Damen Ave.,',
#  '3209 W. Irving Park',
#  'Multiple',
#  '5347 N. Clark St.,',
#  '2954 W. Irving Park Rd.,',
#  'Multiple',
#  '191 Skokie Valley Rd., Highland Park,',
#  'Multiple',
#  '1818 W. Wilson Ave.,',
#  '2517 W. Division St.,',
#  '218 W. Kinzie',
#  'Multiple',
#  '1547 N. Wells St.,',
#  '415 N. Milwaukee Ave.,',
#  '1840 N. Damen Ave.,',
#  '1220 W. Webster Ave.,',
#  '5357 N. Ashland Ave.,',
#  '1834 W. Montrose Ave.,',
#  '615 N. State St.,',
#  'Multiple',
# ...

# %%
# price, ad 칼럼 추가 

df['Price'] = price
df['Address'] = ad

df
# Out:
#    Rank                             Cafe  \
# 0     1                      Old Oak Tap
# 1     2                        Au Cheval
# 2     3                             Xoco
# 3     4                        Al’s Deli
# 4     5           Publican Quality Meats
# 5     6  Hendrickx Belgian Bread Crafter
# 6     7                           Acadia
# 7     8                Birchwood Kitchen
# 8     9                   Cemitas Puebla
# 9    10                             Nana
# 10   11                        Lula Cafe
# 11   12                       Ricobene’s
# 12   13                     Frog n Snail
# 13   14                 Crosby’s Kitchen
# 14   15                  Longman & Eagle
# 15   16                             Bari
# 16   17                          Manny’s
# 17   18                           Eggy’s
# 18   19                    Old Jerusalem
# 19   20             Mindy’s HotChocolate
# 20   21              Olga’s Delicatessen
# 21   22     Dawali Mediterranean Kitchen
# ...

# %%
# rank 를 인덱스로 
df.set_index('Rank', inplace=True)
df.head()
# Out:
#                         Cafe               Menu  \
# Rank
# 1                Old Oak Tap                BLT
# 2                  Au Cheval      Fried Bologna
# 3                       Xoco  Woodland Mushroom
# 4                  Al’s Deli         Roast Beef
# 5     Publican Quality Meats               PB&L
#
#                                                     URL  Price  \
# Rank
# 1     https://www.chicagomag.com/Chicago-Magazine/No...    $10
# 2     https://www.chicagomag.com/Chicago-Magazine/No...     $9
# 3     https://www.chicagomag.com/Chicago-Magazine/No...  $9.50
# 4     https://www.chicagomag.com/Chicago-Magazine/No...  $9.40
# 5     https://www.chicagomag.com/Chicago-Magazine/No...    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
df.to_csv('data/chicago_rank2.csv', sep=',')

# %%
# folium 이용 50개 marker 찍기 

# 주소에 chicago 넣기
# 주소= Multiple 은 건너뛰기
# 경도 위도

# %%
import folium 
import googlemaps 
import numpy as np
import pandas as pd

# %%
gmaps_key = "AIzaSyA-4D2zlsvGdJfR0M_eOutcwCfzCvlictA"
gmaps = googlemaps.Client(key = gmaps_key)

# %%
# 시카고 : 위도 경도 
# map = folium.Map(location=[41.8379, -87.6828], zoom_start=10)
# map

# %%
lat = []
lng = []

eter_val = tqdm(df.index)

for n in eter_val: 
    if df['Address'][n] != "Multiple":                 # 주소= Multiple 은 건너뛰기
        full_add = df['Address'][n] + ' Chicago' # 주소에 chicago 넣기
        gmaps_output = gmaps.geocode(full_add)
        location_output = gmaps_output[0].get('geometry')
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
        
    else: # nan = 그래야 총50개                                             
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#                         Cafe               Menu  \
# Rank
# 1                Old Oak Tap                BLT
# 2                  Au Cheval      Fried Bologna
# 3                       Xoco  Woodland Mushroom
# 4                  Al’s Deli         Roast Beef
# 5     Publican Quality Meats               PB&L
#
#                                                     URL  Price  \
# Rank
# 1     https://www.chicagomag.com/Chicago-Magazine/No...    $10
# 2     https://www.chicagomag.com/Chicago-Magazine/No...     $9
# 3     https://www.chicagomag.com/Chicago-Magazine/No...  $9.50
# 4     https://www.chicagomag.com/Chicago-Magazine/No...  $9.40
# 5     https://www.chicagomag.com/Chicago-Magazine/No...    $10
#
#                        Address
# Rank
# 1        2109 W. Chicago Ave.,
# 2         800 W. Randolph St.,
# 3            445 N. Clark St.,
# 4     914 Noyes St., Evanston,
# 5          825 W. Fulton Mkt.,

# %%
# data 하나하나 꼭 확인하기 -----------------제발---------------------

# lat
# lng
# print(n)
# len(lat)
# len(lng)

# %%
lat
# Out:
# [41.8956049,
#  41.8846582,
#  41.8905226,
#  42.0583217,
#  41.8866036,
#  41.9000869,
#  41.8590541,
#  41.9102031,
#  41.9097558,
#  41.8345302,
#  41.9276207,
#  nan,
#  41.9384419,
#  41.9451044,
#  41.930109,
#  41.8912971,
#  41.8678529,
#  41.8852691,
#  41.9080539,
#  41.91369539999999,
#  41.9536887,
#  nan,
#  41.9794496,
#  41.9541592,
#  nan,
#  42.156691,
#  nan,
#  41.9652627,
#  41.9027178,
#  41.8893683,
#  nan,
#  41.9105258,
#  41.8896188,
#  41.91504990000001,
#  41.9218521,
#  41.9797099,
#  41.9617122,
#  41.89296119999999,
#  nan,
#  41.9047551,
#  41.7913185,
#  42.25178409999999,
#  41.9152875,
#  41.8863622,
#  41.8758102,
#  41.8961134,
#  41.89897850000001,
#  41.9105832,
#  41.8831061,
#  41.9431632]

# %%
df["lat"] = lat
df["lng"] = lng
df.head()
# Out:
#                         Cafe               Menu  \
# Rank
# 1                Old Oak Tap                BLT
# 2                  Au Cheval      Fried Bologna
# 3                       Xoco  Woodland Mushroom
# 4                  Al’s Deli         Roast Beef
# 5     Publican Quality Meats               PB&L
#
#                                                     URL  Price  \
# Rank
# 1     https://www.chicagomag.com/Chicago-Magazine/No...    $10
# 2     https://www.chicagomag.com/Chicago-Magazine/No...     $9
# 3     https://www.chicagomag.com/Chicago-Magazine/No...  $9.50
# 4     https://www.chicagomag.com/Chicago-Magazine/No...  $9.40
# 5     https://www.chicagomag.com/Chicago-Magazine/No...    $10
#
#                        Address        lat        lng
# Rank
# 1        2109 W. Chicago Ave.,  41.895605 -87.679961
# 2         800 W. Randolph St.,  41.884658 -87.647667
# 3            445 N. Clark St.,  41.890523 -87.630783
# 4     914 Noyes St., Evanston,  42.058322 -87.683748
# ...

# %%
map = folium.Map(location = [df["lat"].mean(), df["lng"].mean()], zoom_start=11)

# centre = 중앙 값 mean() = 50개 위도, 경도 
folium.Marker(location = [df["lat"][n], df["lng"][n]], popup= "중앙값").add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
# 각 각 = 50개의 맛집의 위도, 경도 = 지도에

map = folium.Map(location=[df["lat"].mean(), df["lng"].mean()],zoom_start=11)

for n in df.index:
    if df["Address"][n] != "Multiple":
        folium.Marker([df["lat"][n], df["lng"][n]], popup=df["Cafe"][n]).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
